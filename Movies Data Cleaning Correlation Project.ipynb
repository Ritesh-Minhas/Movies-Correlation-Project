# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Reading the Dataset

df = pd.read_csv(r"C:\Users\cd\Desktop\Pandas\movies.csv")
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Exploring the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
# Removing Duplicates (if any)
df = df.drop_duplicates()
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Checking the number of null values
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Correcting the year column, which matches the released column's year
df['released'].str.split(",", 1, expand = True)
df[["Date", "CorrectYear"]] = df['released'].str.split(",", 1, expand = True)
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Corrected the Year
x = df['CorrectYear'].str.split("(", 1, expand = True)
df['CorrectedYear'] = x[0]
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Dropping the Null Values
df = df.dropna()
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Dropping the useless column
df = df.drop(columns = ["Date","CorrectYear"])
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Resetting the index
df.reset_index(drop = True, inplace = True)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5402                               Bad Boys for Life          R     Action
# 5403                              Sonic the Hedgehog         PG     Action
# 5404                                        Dolittle         PG  Adventure
# 5405                            The Call of the Wild         PG  Adventure
# 5406                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Converting the budget and gross column data type to int64
df['budget'] = df['budget'].astype("int64")
df['gross'] = df['gross'].astype("int64")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5407 entries, 0 to 5406
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           5407 non-null   object
#  1   rating         5407 non-null   object
#  2   genre          5407 non-null   object
#  3   year           5407 non-null   int64
#  4   released       5407 non-null   object
#  5   score          5407 non-null   float64
#  6   votes          5407 non-null   float64
#  7   director       5407 non-null   object
#  8   writer         5407 non-null   object
#  9   star           5407 non-null   object
#  10  country        5407 non-null   object
#  11  budget         5407 non-null   int64
#  12  gross          5407 non-null   int64
#  13  company        5407 non-null   object
#  14  runtime        5407 non-null   float64
#  15  CorrectedYear  5407 non-null   object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 676.0+ KB

# %%
# Sorting the dataset by gross column
df = df.sort_values(by = 'gross', ascending = False)
df
# Out:
#                                             name     rating   genre  year  \
# 3718                                      Avatar      PG-13  Action  2009
# 5288                           Avengers: Endgame      PG-13  Action  2019
# 1783                                     Titanic      PG-13   Drama  1997
# 4716  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 5144                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3885                                 Tanner Hall          R   Drama  2009
# 1367                  Philadelphia Experiment II      PG-13  Action  1993
# 2274                                Ginger Snaps  Not Rated   Drama  2000
# 154                                     Parasite          R  Horror  1982
# 1908                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# Using scatter plot to see the correlation between budget and gross column

plt.figure(figsize = (12,5))
plt.scatter(df['budget'], df['gross'], c = "green")
plt.title("Budget vs Gross")
plt.xlabel("Gross")
plt.ylabel("Budget")
plt.show()

# %%
# Plotting Budget vs Gross using seaborn
plt.figure(figsize = (12,5))
sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {"color" : "green"}, line_kws = {"color" : "blue"})

plt.title("Budget vs Gross")
plt.xlabel("Gross")
plt.ylabel("Budget")
plt.show()

# %%
# Finding the correlation

# Converting the CorrectedYear data type to int64
df['CorrectedYear'] = df['CorrectedYear'].astype('int64')

df.corr(method = 'pearson') # method = 'pearson', 'kendall', 'spearman'
# Out:
#                    year     score     votes    budget     gross   runtime  \
# year           1.000000  0.055681  0.204904  0.326740  0.273512  0.074849
# score          0.055681  1.000000  0.474594  0.071552  0.222504  0.414501
# votes          0.204904  0.474594  1.000000  0.439077  0.614432  0.352263
# budget         0.326740  0.071552  0.439077  1.000000  0.740028  0.318353
# gross          0.273512  0.222504  0.614432  0.740028  1.000000  0.275641
# runtime        0.074849  0.414501  0.352263  0.318353  0.275641  1.000000
# CorrectedYear  0.998962  0.061443  0.202215  0.319669  0.268141  0.075183
#
#                CorrectedYear
# year                0.998962
# score               0.061443
# votes               0.202215
# budget              0.319669
# gross               0.268141
# runtime             0.075183
# CorrectedYear       1.000000

# %%
corr_matrix = df.corr(method = 'pearson')

# PLotting the correlation matrix

plt.figure(figsize = (12,8))
sns.heatmap(corr_matrix, annot = True)
plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
# Converting the object data types to numeric values for plotting

df_numerized = df

for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 3718   386       5      0  2009       521    7.8  1100000.0       781    1260
# 5288   388       5      0  2019       132    8.4   903000.0       105     510
# 1783  4895       5      6  1997       528    7.8  1100000.0       781    1260
# 4716  3632       5      0  2015       523    7.8   876000.0       765    1803
# 5144   389       5      0  2018       140    8.4   897000.0       105     510
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 3885  3782       6      6  2009       884    5.8     3500.0       583    2920
# 1367  2958       5      0  1993      1460    4.5     1900.0      1801    3097
# 2274  1589       3      6  2000      1713    6.8    43000.0       948    1680
# 154   2898       6      9  1982      1518    3.9     2300.0       261      54
# 1908  4952       5      4  1997      2139    5.7     5800.0       648     159
#
# ...

# %%
corr_matrix = df_numerized.corr(method = 'pearson')

# PLotting the correlation matrix

plt.figure(figsize = (12,8))
sns.heatmap(corr_matrix, annot = True)
plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
# For finding correlation between every field with other (in form of Series)

corr_mat = df_numerized.corr()

corr_pairs = corr_mat.unstack() # Converts the DataFrame into Series
corr_pairs
# Out:
# name           name             1.000000
#                rating          -0.029220
#                genre            0.010840
#                year             0.025111
#                released        -0.005845
#                                   ...
# CorrectedYear  budget           0.319669
#                gross            0.268141
#                company         -0.019378
#                runtime          0.075183
#                CorrectedYear    1.000000
# Length: 256, dtype: float64

# %%
# Sorting the correlation

sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget         genre           -0.368226
# genre          budget          -0.368226
#                gross           -0.243547
# gross          genre           -0.243547
# rating         budget          -0.203553
#                                   ...
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# CorrectedYear  CorrectedYear    1.000000
# Length: 256, dtype: float64

# %%
# Selecting correlations with values greater than 0.5

high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross          votes            0.614432
# votes          gross            0.614432
# gross          budget           0.740028
# budget         gross            0.740028
# year           CorrectedYear    0.998962
#                                   ...
#                year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# CorrectedYear  CorrectedYear    1.000000
# Length: 22, dtype: float64
